# %% [markdown]
# # Data Exploration
#
# Let's explore the CIFAR 10 dataset.
#
# >The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.
# >
# >The dataset is divided into five training batches and one test batch, each with 10000 images. The test batch contains exactly 1000 randomly-selected images from each class. The training batches contain the remaining images in random order, but some training batches may contain more images from one class than another. Between them, the training batches contain exactly 5000 images from each class.
#
# from: https://www.cs.toronto.edu/~kriz/cifar.html

# %%
# from helperutils.DataLoader import MyDataLoader
import matplotlib.pyplot as plt
import numpy as np
from keras.utils import to_categorical
print("[INFO] loading CIFAR-10 data...")
# (trainX, trainY), (testX, testY), labelNames = MyDataLoader().load_dataset(location='./dataset')
# Out:
# [INFO] loading CIFAR-10 data...

# %% [markdown]
# # Lekker doen

# %%
chris=1

# %%
print(chris)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4d912cec9a34> in <module>
# ----> 1 print(chris)
#
# NameError: name 'chris' is not defined

# %%
print("Training set size X: ", trainX.shape)
print("Training set size Y: ", trainY.shape)


print("Test set size X: ", testX.shape)
print("Test set size Y: ", testY.shape)
# Out:
# Training set size X:  (50000, 32, 32, 3)
# Training set size Y:  (50000, 10)
# Test set size X:  (10000, 32, 32, 3)
# Test set size Y:  (10000, 10)

# %% [markdown]
# The total set if images is split into a 5 to 1 ratio, where 50.000 images are used for training, and 10.000 for testing/validating the trained model.
#
# We also see that each entry is in fact a 3-dimensional matrix, corresponding to the 32x32 image size and depth of 3 (RGB channels respectively).
#
# ![3 layer image](https://www.researchgate.net/profile/Jane_Courtney2/publication/267210444/figure/fig6/AS:295732335661069@1447519491773/A-three-dimensional-RGB-matrix-Each-layer-of-the-matrix-is-a-two-dimensional-matrix.png)
# source: https://www.researchgate.net/profile/Jane_Courtney2

# %% [markdown]
# # Print out a number of entries from the test set, with their label

# %%
filename = 'data_2d/Amsterdam_GE3T/100/pre/FLAIR_53.tif'
from PIL import Image
import cv2
a = Image.open(filename)
img = cv2.imread(filename)
# print(img)
img = img.astype("float") / 255.0
plt.figure()
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-4c48629ea44b> in <module>
#       5 img = cv2.imread(filename)
#       6 # print(img)
# ----> 7 img = img.astype("float") / 255.0
#       8 plt.figure()
#       9 plt.imshow(img)
#
# AttributeError: 'NoneType' object has no attribute 'astype'

# %%
# help(cv2)

# %%
nr_images = 8
image_indices = np.random.randint(0, len(trainX), size=nr_images)

plt.figure(figsize=(15,20))
for (index, i) in enumerate(image_indices):
    plt.subplot(1, len(image_indices), index+1)
    plt.axis('off')
    plt.imshow(trainX[i])
    label = np.argmax(trainY[i])
    plt.title('#{}-{}'.format(i,labelNames[label]))

plt.show()

# %%
nr_images = 8
image_indices = np.random.randint(0, len(testX), size=nr_images)

plt.figure(figsize=(15,20))
for (index, i) in enumerate(image_indices):
    plt.subplot(1, len(image_indices), index+1)
    plt.axis('off')
    plt.imshow(testX[i])
    label = np.argmax(testY[i])
    plt.title('#{}-{}'.format(i,labelNames[label]))

plt.show()
